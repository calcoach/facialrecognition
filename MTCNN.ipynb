# %% [markdown]
# <a href="https://colab.research.google.com/github/calcoach/facialrecognition/blob/master/MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mtcnn
import mtcnn
# print version
print(mtcnn.__version__)
# Out:
# ...
#      |████████████████████████████████| 2.3MB 3.2MB/s
# ...
# Using TensorFlow backend.
# 0.1.0

# %%
from mtcnn.mtcnn import MTCNN
from google.colab.patches import cv2_imshow
from datetime import datetime
import cv2
 
# extract a single face from a given photograph
def extract_face(image, required_size=(160, 160)):

	 detector = MTCNN()
	# detect faces in the image
	 results = detector.detect_faces(image)
	# extract the bounding box from the first face
	 return results
   

image = cv2.imread('/content/foto7.jpg')

now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)
faces = extract_face(image)

now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

for i, face in enumerate (faces):
  x, y, w, h = faces[i]['box']
  cv2.rectangle(image, (x, y), (x + w, y + h), (255, 200, 0), 2)

cv2_imshow(image)
# Out:
# Current Time = 21:04:01
# Current Time = 21:04:05
# <PIL.Image.Image image mode=RGB size=960x960 at 0x7FA3AD7E9DD8>

# %%
# !pip install git+https://github.com/iitzco/faced.git
# Out:
# ...
#   Cloning https://github.com/iitzco/faced.git to /tmp/pip-req-build-s56e_6iz
#   Running command git clone -q https://github.com/iitzco/faced.git /tmp/pip-req-build-s56e_6iz
# ...
#   Created wheel for faced: filename=faced-0.1-cp36-none-any.whl size=27342262 sha256=d965736cec910286e065888852a566223ce75077e343a5f6ce1d3f166d2d2112
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w8fdxio8/wheels/c7/39/87/838ac366089f72d5e65f322faaf6e1ce8bc4a5234c120bebae
# Successfully built faced
# ...

# %%
import cv2 
from faced import FaceDetector
from faced.utils import annotate_image
from datetime import datetime
from google.colab.patches import cv2_imshow


face_detector = FaceDetector()

now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

img = cv2.imread('foto7.jpg')

rgb_img = cv2.cvtColor(img.copy(),cv2.COLOR_BGR2RGB)

bboxes = face_detector.predict(rgb_img)

# Use this utils function to annotate the image.
ann_img = annotate_image(img, bboxes)

now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

# Show the image
cv2_imshow(ann_img)
# Out:
# Current Time = 23:05:46
# Current Time = 23:05:47
# <PIL.Image.Image image mode=RGB size=960x960 at 0x7FA3A97AD320>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from mtcnn.mtcnn import MTCNN
import cv2


def extractFace(frame):

  detector = MTCNN()

  return detector.detect_faces(frame)


VIDEO = "/content/drive/My Drive/Videos/obama.mp4"

fourcc = cv2.VideoWriter_fourcc(*'XVID')
cap = cv2.VideoCapture(VIDEO)

out = cv2.VideoWriter('with10frames.avi', fourcc, 20.0, (int(cap.get(3)),int(cap.get(4))))
ret = True
ret , frame = cap.read()
faces  = extractFace(frame)
count_frame = 1
while ret:

  ret , frame = cap.read()

  count_frame = count_frame+1

  if(count_frame % 10 == 0 ):
     faces = extractFace(frame)

  if (count_frame % 20 == 0):
    print('{}'.format(count_frame/20) + ' segundos procesados')

  for i, feature in enumerate(faces):
     (x,y,w,h) = faces[i]['box']

     if(faces[i]['confidence']>0.95):
        cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 200, 0), 2)

     if count_frame % 10 == 0:
       print(faces[i]['confidence'])
     

  out.write(frame)
# Out:
# 0.9988037347793579
# 1.0 segundos procesados
# 0.9992011189460754
# 0.8386644721031189
# 0.999665379524231
# 2.0 segundos procesados
# 0.9988634586334229
# 0.9998440742492676
# 3.0 segundos procesados
# 0.9993686079978943
# 0.9990110397338867
# 4.0 segundos procesados
# 0.998828113079071
# 0.9992536902427673
# 5.0 segundos procesados
# 0.9987373948097229
# 0.9985631108283997
# 6.0 segundos procesados
# 0.9999953508377075
# 0.9982872605323792
# 0.9724017977714539
# 0.8917150497436523
# 0.8544524312019348
# 0.7317358255386353
# 0.9999986886978149
# 0.9999383687973022
# 0.9991441965103149
# 0.9743315577507019
# 0.852725625038147
# 0.8068748116493225
# 7.0 segundos procesados
# 0.9999927282333374
# 0.9999418258666992
# 0.9661765694618225
# 0.9488245248794556
# 0.7639147043228149
# 0.9999784231185913
# 0.9999032020568848
# 0.9938375353813171
# 0.9484481811523438
# 8.0 segundos procesados
# 0.9999947547912598
# 0.9999603033065796
# 0.9958003163337708
# 0.9747922420501709
# ...
